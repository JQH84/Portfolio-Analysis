# %% [markdown]
#  #  A Whale off the Port(folio)
#  ---
#
#  In this assignment, you'll get to use what you've learned this week to evaluate the performance among various algorithmic, hedge, and mutual fund portfolios and compare them against the S&P 500 Index.

# %%
# Initial imports
import pandas as pd
import numpy as np
import datetime as dt
from pathlib import Path
import seaborn as sns

# %matplotlib inline

# %% [markdown]
# # Data Cleaning
#
# In this section, you will need to read the CSV files into DataFrames and perform any necessary data cleaning steps. After cleaning, combine all DataFrames into a single DataFrame.
#
# Files:
#
# * `whale_returns.csv`: Contains returns of some famous "whale" investors' portfolios.
#
# * `algo_returns.csv`: Contains returns from the in-house trading algorithms from Harold's company.
#
# * `sp500_history.csv`: Contains historical closing prices of the S&P 500 Index.

# %% [markdown]
# ## Whale Returns
#
# Read the Whale Portfolio daily returns and clean the data

# %%
# Reading whale returns
whale = pd.read_csv(Path("Resources/whale_returns.csv") , index_col = "Date" , parse_dates = True , infer_datetime_format=True)

# %%
# Count nulls
whale.isnull().mean()*100
whale.head()
# Out:
#             SOROS FUND MANAGEMENT LLC  PAULSON & CO.INC.   \
# Date
# 2015-03-02                        NaN                 NaN
# 2015-03-03                  -0.001266           -0.004981
# 2015-03-04                   0.002230            0.003241
# 2015-03-05                   0.004016            0.004076
# 2015-03-06                  -0.007905           -0.003574
#
#             TIGER GLOBAL MANAGEMENT LLC  BERKSHIRE HATHAWAY INC
# Date
# 2015-03-02                          NaN                     NaN
# 2015-03-03                    -0.000496               -0.006569
# 2015-03-04                    -0.002534                0.004213
# 2015-03-05                     0.002355                0.006726
# 2015-03-06                    -0.008481               -0.013098

# %%
# Drop nulls
whale.dropna(inplace=True)
whale.isnull().mean()
whale.head()
# Out:
#             SOROS FUND MANAGEMENT LLC  PAULSON & CO.INC.   \
# Date
# 2015-03-03                  -0.001266           -0.004981
# 2015-03-04                   0.002230            0.003241
# 2015-03-05                   0.004016            0.004076
# 2015-03-06                  -0.007905           -0.003574
# 2015-03-09                   0.000582            0.004225
#
#             TIGER GLOBAL MANAGEMENT LLC  BERKSHIRE HATHAWAY INC
# Date
# 2015-03-03                    -0.000496               -0.006569
# 2015-03-04                    -0.002534                0.004213
# 2015-03-05                     0.002355                0.006726
# 2015-03-06                    -0.008481               -0.013098
# 2015-03-09                     0.005843               -0.001652

# %% [markdown]
# ## Algorithmic Daily Returns
#
# Read the algorithmic daily returns and clean the data

# %%
# Reading algorithmic returns
algo = pd.read_csv(Path("Resources/algo_returns.csv") , index_col = "Date" , parse_dates = True , infer_datetime_format=True)

# %%
# Count nulls
algo.isnull().mean()*100
# Out:
# Algo 1    0.000000
# Algo 2    0.483481
# dtype: float64

# %%
# Drop nulls
algo.dropna(inplace=True)
algo.isnull().mean()*100
# Out:
# Algo 1    0.0
# Algo 2    0.0
# dtype: float64

# %% [markdown]
# ## S&P 500 Returns
#
# Read the S&P 500 historic closing prices and create a new daily returns DataFrame from the data.

# %%
# Reading S&P 500 Closing Prices
sp500 = pd.read_csv(Path("Resources/sp500_history.csv") , index_col = "Date" , parse_dates = True , infer_datetime_format=True)

# %%
# Check Data Types
sp500.dtypes
# Out:
# Close    object
# dtype: object

# %%
# Fix Data Types
#sp500['Date'] = pd.to_datetime(sp500['Date'])
sp500['Close'] = sp500['Close'].str.replace('$', '')
sp500['Close'] = sp500['Close'].astype('float')
# Out:
# /opt/anaconda3/envs/dev/lib/python3.7/site-packages/ipykernel_launcher.py:3: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   This is separate from the ipykernel package so we can avoid doing imports until

# %%
# Calculate Daily Returns
sp500_daily_returns = sp500.pct_change()
sp500_daily_returns.head()
# Out:
#                Close
# Date
# 2019-04-23       NaN
# 2019-04-22 -0.008764
# 2019-04-18 -0.001011
# 2019-04-17 -0.001577
# 2019-04-16  0.002279

# %%
# Drop nulls
sp500_daily_returns.dropna(inplace=True)
sp500_daily_returns.head()
# Out:
#                Close
# Date
# 2019-04-22 -0.008764
# 2019-04-18 -0.001011
# 2019-04-17 -0.001577
# 2019-04-16  0.002279
# 2019-04-15 -0.000509

# %%
# Rename `Close` Column to be specific to this portfolio.
sp500_daily_returns.columns=['sp500']
sp500_daily_returns.head()
# Out:
#                sp500
# Date
# 2019-04-22 -0.008764
# 2019-04-18 -0.001011
# 2019-04-17 -0.001577
# 2019-04-16  0.002279
# 2019-04-15 -0.000509

# %% [markdown]
# ## Combine Whale, Algorithmic, and S&P 500 Returns

# %%
# Join Whale Returns, Algorithmic Returns, and the S&P 500 Returns into a single DataFrame with columns for each portfolio's returns.
# an inner join will be used since the whale and algo returns start from 2015 and sp500 data prior will be dropped 
all_returns = pd.concat([whale,algo,sp500_daily_returns] , axis= 1 , join= 'inner')

col_names = ['soros','paulson','tiger','berkshire','algo1','algo2','sp500']
all_returns.columns = col_names
all_returns.head()
# Out:
#                soros   paulson     tiger  berkshire     algo1     algo2  \
# Date
# 2015-03-03 -0.001266 -0.004981 -0.000496  -0.006569 -0.001942 -0.000949
# 2015-03-04  0.002230  0.003241 -0.002534   0.004213 -0.008589  0.002416
# 2015-03-05  0.004016  0.004076  0.002355   0.006726 -0.000955  0.004323
# 2015-03-06 -0.007905 -0.003574 -0.008481  -0.013098 -0.004957 -0.011460
# 2015-03-09  0.000582  0.004225  0.005843  -0.001652 -0.005447  0.001303
#
#                sp500
# Date
# 2015-03-03  0.004408
# 2015-03-04 -0.001195
# 2015-03-05  0.014378
# 2015-03-06 -0.003929
# 2015-03-09  0.017254

# %% [markdown]
# ---

# %% [markdown]
# # Conduct Quantitative Analysis
#
# In this section, you will calculate and visualize performance and risk metrics for the portfolios.

# %% [markdown]
# ## Performance Anlysis
#
# #### Calculate and Plot the daily returns.

# %%
# Plot daily returns of all portfolios
all_returns.plot(figsize=(15,10))
# Out:
# <AxesSubplot:xlabel='Date'>

# %% [markdown]
# #### Calculate and Plot cumulative returns.

# %%
# Calculate cumulative returns of all portfolios
cumulative_return = (1+ all_returns).cumprod() -1
# Plot cumulative returns
cumulative_return.plot(figsize=(15,10))
# Out:
# <AxesSubplot:xlabel='Date'>

# %% [markdown]
# ---

# %% [markdown]
# ## Risk Analysis
#
# Determine the _risk_ of each portfolio:
#
# 1. Create a box plot for each portfolio.
# 2. Calculate the standard deviation for all portfolios
# 4. Determine which portfolios are riskier than the S&P 500
# 5. Calculate the Annualized Standard Deviation

# %% [markdown]
# ### Create a box plot for each portfolio

# %%
# Box plot to visually show risk
all_returns.boxplot(figsize=(10,5))
# Out:
# <AxesSubplot:>

# %% [markdown]
# ### Calculate Standard Deviations

# %%
# Calculate the daily standard deviations of all portfolios
all_returns.std()
# Out:
# soros        0.007896
# paulson      0.007026
# tiger        0.010897
# berkshire    0.012919
# algo1        0.007623
# algo2        0.008341
# sp500        0.008587
# dtype: float64

# %% [markdown]
# ### Determine which portfolios are riskier than the S&P 500

# %%
# Calculate  the daily standard deviation of S&P 500
all_returns['sp500'].std()
# Determine which portfolios are riskier than the S&P 500
spvsall = all_returns.std()-all_returns['sp500'].std()
spvsall.sort_values()
# Out:
# paulson     -0.001561
# algo1       -0.000964
# soros       -0.000691
# algo2       -0.000246
# sp500        0.000000
# tiger        0.002310
# berkshire    0.004332
# dtype: float64

# %% [markdown]
# As we can see from the code output above , the diff between the SP-500 and all other protfilios in terms of Standard Deviation shows Berkshire and Tiger to be the most risky and Paulson along Algo 1 to be the least risky as visulized by the plot below

# %%
spvsall.plot(kind='bar')
# Out:
# <AxesSubplot:>

# %% [markdown]
# ### Calculate the Annualized Standard Deviation

# %%
# Calculate the annualized standard deviation (252 trading days)
anual_std_all_portfolios = all_returns.std()*np.sqrt(252)
anual_std_all_portfolios.plot(kind='bar')
# Out:
# <AxesSubplot:>

# %% [markdown]
# ---

# %% [markdown]
# ## Rolling Statistics
#
# Risk changes over time. Analyze the rolling statistics for Risk and Beta.
#
# 1. Calculate and plot the rolling standard deviation for all portfolios using a 21-day window
# 2. Calculate the correlation between each stock to determine which portfolios may mimick the S&P 500
# 3. Choose one portfolio, then calculate and plot the 60-day rolling beta between it and the S&P 500

# %% [markdown]
# ### Calculate and plot rolling `std` for all portfolios with 21-day window

# %%
# Calculate the rolling standard deviation for all portfolios using a 21-day window
all_returns_rolling = all_returns.rolling(window=21).std()
# Plot the rolling standard deviation
all_returns_rolling.plot(figsize=(10,5))
# Out:
# <AxesSubplot:xlabel='Date'>

# %% [markdown]
# ### Calculate and plot the correlation

# %%
# Calculate the correlation
all_returns_correlation = all_returns.corr()
# Display de correlation matrix , Seaborn can be used to visulize the matrix with a heatmap 

all_returns_correlation
sns.heatmap(all_returns_correlation, vmin=-1 , vmax=1)
# Out:
# <AxesSubplot:>

# %% [markdown]
# ### Calculate and Plot Beta for a chosen portfolio and the S&P 500

# %%
# Calculate covariance of a single portfolio -- Will plot all profolios and comment out all but one after viewing
#all_returns.columns -- use this code to get the col names for cleaner naming 

# soros_cov = all_returns['soros'].rolling(window=60).cov(all_returns['sp500'])
# paulson_cov = all_returns['paulson'].rolling(window=60).cov(all_returns['sp500'])
# tiger_cov =  all_returns['tiger'].rolling(window=60).cov(all_returns['sp500'])
berkshire_cov = all_returns['berkshire'].rolling(window=60).cov(all_returns['sp500'])
# algo1_cov  = all_returns['algo1'].rolling(window=60).cov(all_returns['sp500'])
# algo2_cov = all_returns['algo2'].rolling(window=60).cov(all_returns['sp500'])
# sp500_cov = all_returns['sp500'].rolling(window=60).cov(all_returns['sp500'])

# Calculate variance of S&P 500
sp500_var = all_returns['sp500'].var()

# Computing beta
# soros_beta = soros_cov /sp500_var

# paulson_beta = paulson_cov / sp500_var

# tiger_beta = tiger_cov / sp500_var

berkshire_beta = berkshire_cov / sp500_var

# algo1_beta = algo1_cov / sp500_var

# algo2_beta = algo2_cov / sp500_var

# Plot beta trend
# beta_plt = soros_beta.plot(figsize=(15,5))
# paulson_beta.plot(ax = beta_plt)
# tiger_beta.plot(ax= beta_plt)
berkshire_beta.plot()
# algo1_beta.plot( ax = beta_plt)
# algo2_beta.plot(ax = beta_plt)

# beta_plt.legend(['Soros', 'Paulson' , "Tiger" , "Berkshire" , 'Algo 1', 'Algo 2'])
# Out:
# <AxesSubplot:xlabel='Date'>

# %% [markdown]
# ## Rolling Statistics Challenge: Exponentially Weighted Average
#
# An alternative way to calculate a rolling window is to take the exponentially weighted moving average. This is like a moving window average, but it assigns greater importance to more recent observations. Try calculating the [`ewm`](https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.DataFrame.ewm.html) with a 21-day half-life.

# %%
# Use `ewm` to calculate the rolling window
ewm = all_returns.ewm(21)
# Out:
# ExponentialMovingWindow [com=21,min_periods=1,adjust=True,ignore_na=False,axis=0]

# %% [markdown]
# ---

# %% [markdown]
# # Sharpe Ratios
# In reality, investment managers and thier institutional investors look at the ratio of return-to-risk, and not just returns alone. After all, if you could invest in one of two portfolios, and each offered the same 10% return, yet one offered lower risk, you'd take that one, right?
#
# ### Using the daily returns, calculate and visualize the Sharpe ratios using a bar plot

# %%
# Annualized Sharpe Ratios
# we wil compute the annulized shapre ratios between the SP-500 and the rest of the portfolio 
sharpe_ratios = ((all_returns.mean()-all_returns['sp500'].mean())* 252) / (all_returns.std() * np.sqrt(252))
sharpe_ratios
# Out:
# soros        0.906838
# paulson      0.142411
# tiger        0.278448
# berkshire    0.951436
# algo1        1.953767
# algo2        1.018189
# sp500        0.000000
# dtype: float64

# %%
# Visualize the sharpe ratios as a bar plot
sharpe_ratios.plot(kind= 'bar' , title= 'Sharpe Ratios For Portofolios to S&P500')
# Out:
# <AxesSubplot:title={'center':'Sharpe Ratios For Portofolios to S&P500'}>

# %% [markdown]
# ### Determine whether the algorithmic strategies outperform both the market (S&P 500) and the whales portfolios.
#
# The Algorithmic Strategies clearly are ahead of the S&P 500 and only Algo 1 is ahead of both the Whale and S&P 500.

# %% [markdown]
# ---

# %% [markdown]
# # Create Custom Portfolio
#
# In this section, you will build your own portfolio of stocks, calculate the returns, and compare the results to the Whale Portfolios and the S&P 500.
#
# 1. Choose 3-5 custom stocks with at last 1 year's worth of historic prices and create a DataFrame of the closing prices and dates for each stock.
# 2. Calculate the weighted returns for the portfolio assuming an equal number of shares for each stock
# 3. Join your portfolio returns to the DataFrame that contains all of the portfolio returns
# 4. Re-run the performance and risk analysis with your portfolio to see how it compares to the others
# 5. Include correlation analysis to determine which stocks (if any) are correlated

# %% [markdown]
# ## Choose 3-5 custom stocks with at last 1 year's worth of historic prices and create a DataFrame of the closing prices and dates for each stock.

# %%
# Reading data from 1st stock
BK_stock = pd.read_csv("Resources/BK_historical.csv" , index_col=['Date'] , parse_dates=True , infer_datetime_format=True )

# %%
# Reading data from 2nd stock
HPE_stock = pd.read_csv("Resources/HPE_historical.csv", index_col=['Date'] , parse_dates=True , infer_datetime_format=True )

# %%
# Reading data from 3rd stock
PayPl_stock  = pd.read_csv("Resources/PayPal_historical.csv", index_col=['Date'] , parse_dates=True , infer_datetime_format=True )

# %%
# Combine all stocks in a single DataFrame
my_stocks = pd.concat([BK_stock, HPE_stock, PayPl_stock], join= 'inner' , axis=1)

# %%
# Reset Date index
my_stocks.head()
# Out:
#                BK   HPE   pypl
# Date
# 2015-10-19  40.17  9.64  34.84
# 2015-10-20  41.25  9.83  34.87
# 2015-10-21  40.84  9.60  33.83
# 2015-10-22  41.65  9.87  34.79
# 2015-10-23  42.25  9.90  34.99

# %%
# Reorganize portfolio data by having a column per symbol

# %%
# Calculate daily returns
my_stocks_returns = my_stocks.pct_change()
# Drop NAs
my_stocks_returns.dropna(inplace=True)
# Display sample data
my_stocks_returns.head(10)
# Out:
#                   BK       HPE      pypl
# Date
# 2015-10-20  0.026886  0.019710  0.000861
# 2015-10-21 -0.009939 -0.023398 -0.029825
# 2015-10-22  0.019833  0.028125  0.028377
# 2015-10-23  0.014406  0.003040  0.005749
# 2015-10-26 -0.008521 -0.034343  0.041440
# 2015-10-27 -0.004297 -0.041841 -0.013721
# 2015-10-28  0.032606  0.034934  0.016138
# 2015-10-29 -0.014395 -0.020042 -0.016703
# 2015-10-30 -0.018846 -0.077503  0.002785
# 2015-11-02  0.014406 -0.015169  0.027215

# %% [markdown]
# ## Calculate the weighted returns for the portfolio assuming an equal number of shares for each stock

# %%
# Set weights
weights = [1/3, 1/3, 1/3]

# Calculate portfolio return
my_stocks_returns_weighted = my_stocks_returns.dot(weights)

#Fix the column name 
my_stocks_returns_weighted.columns = ['my_stocks']

# Display sample data
my_stocks_returns_weighted.head()
# Out:
# Date
# 2015-10-20    0.015819
# 2015-10-21   -0.021054
# 2015-10-22    0.025445
# 2015-10-23    0.007731
# 2015-10-26   -0.000475
# dtype: float64

# %% [markdown]
# ## Join your portfolio returns to the DataFrame that contains all of the portfolio returns

# %%
# Join your returns DataFrame to the original returns DataFrame
combined_returns = pd.concat([all_returns, my_stocks_returns_weighted],join="inner", axis=1)
col_names_2 = ['soros','paulson','tiger','berkshire','algo1','algo2','sp500','my_stocks']
combined_returns.columns = col_names_2
combined_returns.head()
# Out:
#                soros   paulson     tiger  berkshire     algo1     algo2  \
# Date
# 2015-10-20 -0.002328 -0.008878  0.001415  -0.008821 -0.012867  0.011739
# 2015-10-21 -0.013934 -0.010111 -0.006908  -0.015734 -0.000411 -0.013079
# 2015-10-22  0.009900 -0.008222  0.006310   0.007892  0.001805  0.006745
# 2015-10-23  0.012022  0.018284  0.008114   0.017094  0.000042  0.005278
# 2015-10-26  0.005491  0.003900  0.004319   0.004007 -0.002997 -0.004346
#
#                sp500  my_stocks
# Date
# 2015-10-20  0.005860   0.015819
# 2015-10-21 -0.016356  -0.021054
# 2015-10-22 -0.010910   0.025445
# 2015-10-23  0.001917   0.007731
# 2015-10-26  0.002561  -0.000475

# %%
# Only compare dates where return data exists for all the stocks (drop NaNs)
combined_returns.isna().mean()
# Out:
# soros        0.0
# paulson      0.0
# tiger        0.0
# berkshire    0.0
# algo1        0.0
# algo2        0.0
# sp500        0.0
# my_stocks    0.0
# dtype: float64

# %% [markdown]
# ## Re-run the risk analysis with your portfolio to see how it compares to the others

# %% [markdown]
# ### Calculate the Annualized Standard Deviation

# %%
# Calculate the annualized `std`
annual_final_portfolio = combined_returns.std()*np.sqrt(252)
annual_final_portfolio.head(10)
# Out:
# soros        0.124946
# paulson      0.114662
# tiger        0.180184
# berkshire    0.206389
# algo1        0.119180
# algo2        0.131820
# sp500        0.131439
# my_stocks    0.206772
# dtype: float64

# %% [markdown]
# ### Calculate and plot rolling `std` with 21-day window

# %%
# Calculate rolling standard deviation
rolling_returns_std = combined_returns.rolling(window=21).std()
# Plot rolling standard deviation
rolling_returns_std.plot(figsize=(15,10))
# Out:
# <AxesSubplot:xlabel='Date'>

# %% [markdown]
# ### Calculate and plot the correlation

# %%
# Calculate and plot the correlation
final_returns_corr = combined_returns.corr()
sns.heatmap(final_returns_corr , vmin= -1 , vmax=1)
# Out:
# <AxesSubplot:>

# %% [markdown]
# ### Calculate and Plot Rolling 60-day Beta for Your Portfolio compared to the S&P 500

# %%
# Calculate and plot Beta
my_stocks_cov = combined_returns['my_stocks'].rolling(window=60).cov(all_returns['sp500'])
my_stocks_beta = my_stocks_cov / sp500_var
my_stocks_beta.plot()
# Out:
# <AxesSubplot:xlabel='Date'>

# %% [markdown]
# ### Using the daily returns, calculate and visualize the Sharpe ratios using a bar plot

# %%
# Calculate Annualized Sharpe Ratios
new_sharpe_ratio = (combined_returns.mean() - combined_returns['sp500'].mean()) / combined_returns.std() * np.sqrt(252)
new_sharpe_ratio.head(10)
# Out:
# soros        1.244313
# paulson      0.372784
# tiger        0.387054
# berkshire    1.260696
# algo1        2.214574
# algo2        1.357299
# sp500        0.000000
# my_stocks    1.501804
# dtype: float64

# %%
# Visualize the sharpe ratios as a bar plot
new_sharpe_ratio.plot(kind='bar',title='Sharpe Ratios including Custom Stock')
# Out:
# <AxesSubplot:title={'center':'Sharpe Ratios including Custom Stock'}>

# %% [markdown]
# ### How does your portfolio do?
#
# My Portfolio is considered second best after Algo 1 and still is better than Algo 2 by a slight difference of 0.144505
